# %%
import pandas as pd
import time

from pymongo import MongoClient
from pymongo.server_api import ServerApi

from selenium import webdriver
from selenium.webdriver.edge.service import Service
from selenium.webdriver.common.by import By

# %%
driver_path = "C:/Users/maouz/Downloads/edgedriver_win64/msedgedriver.exe"
service = Service(executable_path = driver_path)
driver = webdriver.Edge(service = service)

url = "https://www.bps.go.id/id/statistics-table/2/NDYxIzI=/pengeluaran-per-kapita-yang-disesuaikan-menurut-jenis-kelamin--ribu-rupiah-orang-tahun-.html"
driver.get(url = url)
time.sleep(5)

table_element = driver.find_element(By.TAG_NAME , "table")
table_html = table_element.get_attribute("outerHTML")

df = pd.read_html(table_html)[0]
print(df)

df.to_excel("pengeluaran perkapita berdasarkan jenis kelamin.xlsx")
# Out:
# C:\Users\maouz\AppData\Local\Temp\ipykernel_8828\3228796587.py:12: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(table_html)[0]
#     Provinsi/Kabupaten/Kota  \
#     Provinsi/Kabupaten/Kota
#     Provinsi/Kabupaten/Kota
#     Provinsi/Kabupaten/Kota
# 0                      ACEH
# 1                  Simeulue
# 2              Aceh Singkil
# 3              Aceh Selatan
# 4             Aceh Tenggara
# ..                      ...
# 574        Mamberamo Tengah
# 575                  Yalimo
# 576                Yahukimo
# 577      Pegunungan Bintang
# 578               INDONESIA
#
#                                                                          Unnamed: 1_level_0  \
#     Pengeluaran per Kapita yang Disesuaikan menurut Jenis Kelamin (Ribu Rupiah/Orang/Tahun)
# ...

# %%
data = pd.read_excel("pengeluaran perkapita berdasarkan jenis kelamin.xlsx")
filtered_data = data.iloc[203:239]
filtered_data = filtered_data.drop(['Unnamed: 0', 'Unnamed: 1_level_0', 'Unnamed: 2_level_0', 'Unnamed: 4_level_0', 'Unnamed: 5_level_0'], axis=1)
filtered_data = filtered_data.rename(columns={'Provinsi/Kabupaten/Kota' : 'wilayah', 'Unnamed: 3_level_0' : 'Pria', 'Unnamed: 6_level_0' : 'Wanita'})

print(filtered_data)
filtered_data.to_excel("formatted_data.xlsx", index=False)
# Out:
#              wilayah    Pria  Wanita
# 203      JAWA TENGAH  16.690  10.892
# 204          Cilacap  17.148   8.011
# 205         Banyumas  18.616   8.892
# 206      Purbalingga  15.015  10.573
# 207     Banjarnegara  11.970   9.394
# 208          Kebumen  13.291   9.324
# 209        Purworejo  12.917  11.111
# 210         Wonosobo  16.302  10.464
# 211         Magelang  15.371   9.791
# 212         Boyolali  19.084  13.648
# 213           Klaten  14.916  12.935
# 214        Sukoharjo  13.837  12.061
# 215         Wonogiri  14.464   9.460
# 216      Karanganyar  13.384  12.225
# 217           Sragen  18.731  12.316
# 218         Grobogan  17.099   8.330
# 219            Blora  15.952   6.721
# 220          Rembang  17.238   8.041
# 221             Pati  16.428  10.876
# 222            Kudus  16.796  11.628
# 223           Jepara  16.141   9.432
# 224            Demak  16.767   9.832
# 225         Semarang  14.473  13.053
# 226       Temanggung  12.389   9.783
# ...

# %%
url = "mongodb+srv://maozalpandu123:crims0n123@cluster0.spabcda.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"

client = MongoClient(url)
db = client['big_data_uts']
collection = db['data_pengeluaran_perkapita']

data_dict = filtered_data.to_dict(orient='records')
collection.insert_many(data_dict)
# Out:
# InsertManyResult([ObjectId('681f78e6b20fb03fe975b552'), ObjectId('681f78e6b20fb03fe975b553'), ObjectId('681f78e6b20fb03fe975b554'), ObjectId('681f78e6b20fb03fe975b555'), ObjectId('681f78e6b20fb03fe975b556'), ObjectId('681f78e6b20fb03fe975b557'), ObjectId('681f78e6b20fb03fe975b558'), ObjectId('681f78e6b20fb03fe975b559'), ObjectId('681f78e6b20fb03fe975b55a'), ObjectId('681f78e6b20fb03fe975b55b'), ObjectId('681f78e6b20fb03fe975b55c'), ObjectId('681f78e6b20fb03fe975b55d'), ObjectId('681f78e6b20fb03fe975b55e'), ObjectId('681f78e6b20fb03fe975b55f'), ObjectId('681f78e6b20fb03fe975b560'), ObjectId('681f78e6b20fb03fe975b561'), ObjectId('681f78e6b20fb03fe975b562'), ObjectId('681f78e6b20fb03fe975b563'), ObjectId('681f78e6b20fb03fe975b564'), ObjectId('681f78e6b20fb03fe975b565'), ObjectId('681f78e6b20fb03fe975b566'), ObjectId('681f78e6b20fb03fe975b567'), ObjectId('681f78e6b20fb03fe975b568'), ObjectId('681f78e6b20fb03fe975b569'), ObjectId('681f78e6b20fb03fe975b56a'), ObjectId('681f78e6b20fb03fe975
# ...
